# %% [markdown]
# ```
# 192465
# Hungchiuming
# 2 BS ITE
# ```

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

from_member = input("From: ")
to_member = input("To: ")

def relationship_status(from_member, to_member):
    if from_member in social_graph [to_member]["following"] and to_member in social_graph [from_member]["following"]:
        return "friends"
    elif from_member in social_graph [to_member]["following"]:
        return "followed by"
    elif to_member in social_graph [from_member]["following"]:
        return "follower"
    else:
        return None
    
print (relationship_status(from_member, to_member))
# Out:
# From: @chums
# To: @jobenilagan
# followed by

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]



        
        
def get_winner(board):
    
    winner = None
     
     ## check diagonals
    
    lr=([board[i][i] for i, v in enumerate(board)])
    rl=([board[i][2-i] for i, v in enumerate(board)])
    if lr == ['X', 'X', 'X']:
        return "X"
    elif rl == ['O', 'O', 'O']:
        return "O"

     ## check rows
    for i in range(0,3):
        if board[i]== ['X','X','X']:
            return "X"
        elif board[i]== ['O', 'O', 'O']:
            return "O"

     ## check columns
    vs= [x for x in zip(*board)]
    if vs[i] == ('X', 'X', 'X'):
        return "X"
    elif vs[i] == ('O', 'O', 'O'):
        return "O"
    

    
print (get_winner(board1))
# Out:
# X

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}

source=input("Enter source: ")
destination=input("Enter destination: ")

def eta(source,destination):
    pass
    if source != destination:
        if(source == "upd"):
            source = ("upd","admu")
        elif(source == "admu"):
            source = ("admu","dlsu")
        elif(source == "dlsu"):
            source = ("dlsu","upd")

        if(destination == "admu"):
            destination = ("upd","admu")
        elif(destination == "dlsu"):
            destination = ("admu","dlsu")
        elif(destination == "upd"):
            destination = ("dlsu","upd")

        if source == destination:
            t = legs[source]["travel_time_mins"]
        elif source != destination:
            t = legs[source]["travel_time_mins"] + legs[destination]["travel_time_mins"]
        
    elif source==destination:
        t = "100"
    
    return t

print ("ETA: ",(eta(source,destination)))
# Out:
# Enter source: admu
# Enter destination: upd
# ETA:  90
